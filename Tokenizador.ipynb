# %%
import pandas as pd
import javalang as javalang


data = pd.read_csv('nuevo_labels.csv')

# %%
# Función para tokenizar el código Java
def tokenize_java_code(java_code):
    tokens = []
    try:
        token_generator = javalang.tokenizer.tokenize(java_code)
        for token in token_generator:
            tokens.append(token.__class__.__name__)
    except Exception as e:
        print("Tokenization error:", e)
    return tokens

    #return tokens

# Ejemplo de uso
#code = data["sub1"][0]

#tokens = tokenize_java_code(code)

# Imprimir los tokens
#for token in tokens:
   # print(token[0])

    

data['sub1'] = data['sub1'].apply(tokenize_java_code)
data['sub2'] = data['sub2'].apply(tokenize_java_code)

# %%
data["sub1"][0]
# Out:
# ['Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Separator',
#  'Modifier',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Modifier',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Operator',
#  'Keyword',
#  'BasicType',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Modifier',
#  'Modifier',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Identifier',
#  'Operator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Identifier',
#  'Operator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Operator',
#  'Keyword',
#  'BasicType',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Keyword',
#  'Identifier',
#  'Operator',
#  'Operator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Keyword',
#  'Identifier',
#  'Operator',
#  'Operator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Modifier',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Keyword',
#  'Identifier',
#  'Operator',
#  'Operator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Modifier',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'BasicType',
#  'Separator',
#  'Operator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Modifier',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Modifier',
#  'Modifier',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'BasicType',
#  'Identifier',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Operator',
#  'DecimalInteger',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Operator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Keyword',
#  'Identifier',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Identifier',
#  'Separator',
#  'Separator',
#  'Separator',
#  'Separator']

# %%
data
# Out:
#                                                   sub1  \
# 0    [Keyword, Identifier, Separator, Identifier, S...
# 1    [Keyword, Identifier, Separator, Identifier, S...
# 2    [Keyword, Identifier, Separator, Identifier, S...
# 3    [Keyword, Identifier, Separator, Identifier, S...
# 4    [Keyword, Identifier, Separator, Identifier, S...
# ..                                                 ...
# 906  [Keyword, Identifier, Separator, Identifier, S...
# 907  [Keyword, Identifier, Separator, Identifier, S...
# 908  [Keyword, Identifier, Separator, Identifier, S...
# 909  [Keyword, Identifier, Separator, Identifier, S...
# 910  [Keyword, Identifier, Separator, Identifier, S...
#
#                                                   sub2  problem  verdict
# 0    [Keyword, Identifier, Separator, Identifier, S...       19        0
# 1    [Keyword, Identifier, Separator, Identifier, S...       20        0
# 2    [Keyword, Identifier, Separator, Identifier, S...       14        1
# 3    [Keyword, Identifier, Separator, Identifier, S...        6        0
# 4    [Keyword, Identifier, Separator, Identifier, S...       15        0
# ..                                                 ...      ...      ...
# 906  [Keyword, Identifier, Separator, Identifier, S...        8        1
# 907  [Keyword, Identifier, Separator, Identifier, S...        4        0
# 908  [Keyword, Identifier, Separator, Identifier, S...       17        0
# 909  [Keyword, Identifier, Separator, Identifier, S...       15        1
# 910  [Keyword, Identifier, Separator, Identifier, S...        4        0
#
# [911 rows x 4 columns]

# %%
data.to_csv('labels_tokenized.csv', index=False)
